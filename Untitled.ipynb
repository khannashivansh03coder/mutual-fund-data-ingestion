# %%
import os

folder_path = "/Users/shivanshkhanna/Documents/mutual_fund_project/data/raw"

files = os.listdir(folder_path)

print(files)
# Out:
# ['01_fund_master.csv', '02_nav_history.csv', '04_monthly_sip_inflows.csv', '07_scheme_performance.csv', '10_benchmark_indices.csv', '08_investor_transactions.csv', '09_portfolio_holdings.csv', '05_category_inflows.csv', '03_aum_by_fund_house.csv', '06_industry_folio_count.csv']

# %%
import pandas as pd
import os

folder_path = "/Users/shivanshkhanna/Documents/mutual_fund_project/data/raw"

files = os.listdir(folder_path)

for file in files:
    if file.endswith(".csv"):
        print("\n" + "="*50)
        print("FILE:", file)

        df = pd.read_csv(os.path.join(folder_path, file))

        print("Shape:", df.shape)

        print("\nData Types:")
        print(df.dtypes)

        print("\nFirst 5 Rows:")
        print(df.head())
# Out:
# ...
# FILE: 01_fund_master.csv
# Shape: (40, 15)
#
# Data Types:
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
#
# First 5 Rows:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# ...

# %%
import pandas as pd

fund_master = pd.read_csv(
    "/Users/shivanshkhanna/Documents/mutual_fund_project/data/raw/01_fund_master.csv"
)

print("Shape:")
print(fund_master.shape)

print("\nColumns:")
print(fund_master.columns)

fund_master.head()
# Out:
# Shape:
# (40, 15)
#
# Columns:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='object')
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# ...

# %%
print("Unique Fund Houses")
print(fund_master["fund_house"].unique())

print("\nTotal Fund Houses:")
print(fund_master["fund_house"].nunique())


print("\nUnique Categories")
print(fund_master["category"].unique())


print("\nUnique Sub Categories")
print(fund_master["sub_category"].unique())


print("\nUnique Risk Categories")
print(fund_master["risk_category"].unique())
# Out:
# Unique Fund Houses
# ['SBI Mutual Fund' 'HDFC Mutual Fund' 'ICICI Prudential MF'
#  'Nippon India MF' 'Kotak Mahindra MF' 'Axis Mutual Fund'
#  'Aditya Birla Sun Life MF' 'UTI Mutual Fund' 'Mirae Asset MF'
#  'DSP Mutual Fund']
#
# Total Fund Houses:
# 10
#
# Unique Categories
# ['Equity' 'Debt']
#
# Unique Sub Categories
# ['Large Cap' 'Small Cap' 'Gilt' 'Mid Cap' 'Short Duration' 'Value'
#  'Liquid' 'Index/ETF' 'Flexi Cap' 'Index' 'Large & Mid Cap' 'ELSS']
#
# Unique Risk Categories
# ['Moderate' 'Very High' 'Low' 'High' 'Moderately High']

# %%
nav_history = pd.read_csv(
    "/Users/shivanshkhanna/Documents/mutual_fund_project/data/raw/02_nav_history.csv"
)

print("Shape:")
print(nav_history.shape)

print("\nColumns:")
print(nav_history.columns)

nav_history.head()
# Out:
# Shape:
# (46000, 3)
#
# Columns:
# Index(['amfi_code', 'date', 'nav'], dtype='object')
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
fund_codes = set(fund_master["amfi_code"])

nav_codes = set(nav_history["amfi_code"])

missing_codes = fund_codes - nav_codes

print("Fund Master Codes:", len(fund_codes))
print("NAV History Codes:", len(nav_codes))

print("\nMissing Codes:")
print(missing_codes)

print("\nTotal Missing:", len(missing_codes))
# Out:
# Fund Master Codes: 40
# NAV History Codes: 40
#
# Missing Codes:
# set()
#
# Total Missing: 0

# %%
print("FUND MASTER")

print("\nMissing Values:")
print(fund_master.isnull().sum())

print("\nDuplicate Rows:")
print(fund_master.duplicated().sum())


print("\n" + "="*50)

print("NAV HISTORY")

print("\nMissing Values:")
print(nav_history.isnull().sum())

print("\nDuplicate Rows:")
print(nav_history.duplicated().sum())
# Out:
# FUND MASTER
#
# Missing Values:
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# ...
# NAV HISTORY
#
# Missing Values:
# amfi_code    0
# date         0
# nav          0
# dtype: int64
#
# Duplicate Rows:
# 0

# %%
import requests

url = "https://api.mfapi.in/mf/125497"

response = requests.get(url)

print("Status Code:", response.status_code)

data = response.json()

print(type(data))
print(data.keys())
# Out:
# Status Code: 200
# <class 'dict'>
# dict_keys(['meta', 'data', 'status'])

# %%
print(data["meta"])

print("\nFirst 5 NAV records:")
print(data["data"][:5])
# Out:
# {'fund_house': 'SBI Mutual Fund', 'scheme_type': 'Open Ended Schemes', 'scheme_category': 'Equity Scheme - Small Cap Fund', 'scheme_code': 125497, 'scheme_name': 'SBI Small Cap Fund - Direct Plan - Growth', 'isin_growth': 'INF200K01T51', 'isin_div_reinvestment': None}
#
# First 5 NAV records:
# [{'date': '01-06-2026', 'nav': '192.31950'}, {'date': '31-05-2026', 'nav': '193.68360'}, {'date': '29-05-2026', 'nav': '193.68480'}, {'date': '27-05-2026', 'nav': '195.05010'}, {'date': '26-05-2026', 'nav': '194.22580'}]

# %%
import pandas as pd

nav_df = pd.DataFrame(data["data"])

nav_df["scheme_code"] = data["meta"]["scheme_code"]
nav_df["scheme_name"] = data["meta"]["scheme_name"]

nav_df.to_csv(
    "/Users/shivanshkhanna/Documents/mutual_fund_project/data/raw/HDFC_Top_100_live_nav.csv",
    index=False
)

nav_df.head()
# Out:
#          date        nav  scheme_code  \
# 0  01-06-2026  192.31950       125497
# 1  31-05-2026  193.68360       125497
# 2  29-05-2026  193.68480       125497
# 3  27-05-2026  195.05010       125497
# 4  26-05-2026  194.22580       125497
#
#                                  scheme_name
# 0  SBI Small Cap Fund - Direct Plan - Growth
# 1  SBI Small Cap Fund - Direct Plan - Growth
# 2  SBI Small Cap Fund - Direct Plan - Growth
# 3  SBI Small Cap Fund - Direct Plan - Growth
# 4  SBI Small Cap Fund - Direct Plan - Growth

# %%
import requests
import pandas as pd

schemes = {
    "SBI_Bluechip": 119551,
    "ICICI_Bluechip": 120503,
    "Nippon_Large_Cap": 118632,
    "Axis_Bluechip": 119092,
    "Kotak_Bluechip": 120841
}

for name, code in schemes.items():

    url = f"https://api.mfapi.in/mf/{code}"

    response = requests.get(url)

    if response.status_code == 200:

        data = response.json()

        df = pd.DataFrame(data["data"])

        df["scheme_code"] = code
        df["scheme_name"] = data["meta"]["scheme_name"]

        filename = f"{name}.csv"

        df.to_csv(filename, index=False)

        print(f"Saved {filename}")

    else:
        print(f"Failed for {code}")
# Out:
# Saved SBI_Bluechip.csv
# Saved ICICI_Bluechip.csv
# Saved Nippon_Large_Cap.csv
# Saved Axis_Bluechip.csv
# Saved Kotak_Bluechip.csv

# %%
import requests
import pandas as pd

save_path = "/Users/shivanshkhanna/Documents/mutual_fund_project/data/raw/"

schemes = {
    "SBI_Bluechip": 119551,
    "ICICI_Bluechip": 120503,
    "Nippon_Large_Cap": 118632,
    "Axis_Bluechip": 119092,
    "Kotak_Bluechip": 120841
}

for name, code in schemes.items():
    url = f"https://api.mfapi.in/mf/{code}"
    response = requests.get(url)
    data = response.json()

    df = pd.DataFrame(data["data"])
    df["scheme_code"] = code
    df["scheme_name"] = data["meta"]["scheme_name"]

    filename = save_path + f"{name}_live_nav.csv"
    df.to_csv(filename, index=False)

    print("Saved:", filename)
# Out:
# Saved: /Users/shivanshkhanna/Documents/mutual_fund_project/data/raw/SBI_Bluechip_live_nav.csv
# Saved: /Users/shivanshkhanna/Documents/mutual_fund_project/data/raw/ICICI_Bluechip_live_nav.csv
# Saved: /Users/shivanshkhanna/Documents/mutual_fund_project/data/raw/Nippon_Large_Cap_live_nav.csv
# Saved: /Users/shivanshkhanna/Documents/mutual_fund_project/data/raw/Axis_Bluechip_live_nav.csv
# Saved: /Users/shivanshkhanna/Documents/mutual_fund_project/data/raw/Kotak_Bluechip_live_nav.csv
