# %%
import pandas as pd

df = pd.read_csv("data/processed/fund_scorecard.csv")
print(df.columns)
# Out:
# Index(['amfi_code', 'cagr_1yr', 'cagr_3yr', 'cagr_5yr', 'scheme_name',
#        'fund_house', 'category', 'expense_ratio_pct', 'sharpe_ratio',
#        'sortino_ratio', 'max_drawdown', 'max_drawdown_date', 'alpha', 'beta',
#        'return_rank', 'sharpe_rank', 'alpha_rank', 'expense_rank',
#        'drawdown_rank', 'fund_score'],
#       dtype='object')
